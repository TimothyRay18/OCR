# %%
import cv2
import pytesseract
import numpy as np
import matplotlib.pyplot as plt

# %%
# Untuk tesseract di windows
# pytesseract.pytesseract.tesseract_cmd = r'C:/Program Files/Tesseract-OCR/tesseract.exe'

# %% [markdown]
# ## Text to image

# %%
img = cv2.imread('ComicSans.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
def plot_image(img: np.array):
    plt.figure(figsize=(6, 6))
    plt.imshow(img, cmap='gray');

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:
# ABCDEFGHIJ KLM
# NOPQRSTUVWXYZ
# abcdefghijklm
# nopaqrstuvwxyz
# 1234567890

# %%
plot_image(img)

# %%
img = cv2.imread('Jokerman.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:
# ABCDEFGHIFKLM
# NOPQRSTUVWXYZ
# abedefghijkim
# hopgrstuywxyz
#
# 1234567846

# %%
plot_image(img)

# %%
img = cv2.imread('OldEnglish.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:
# ABCDEFOHIFLLM
# NOPECRSTAVWXBZ
# abrdefghijkim
# nopgrstubwxps
# 1234567890

# %%
plot_image(img)

# %%
img = cv2.imread('whitespace2.png')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:
# Jeddi. Timothy
#
# Fedly Septian

# %%
plot_image(img)

# %%
img = cv2.imread('Sharp.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:

# %%
plot_image(img)

# %%
img = cv2.imread('3DNoise.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:

# %%
plot_image(img)

# %%
img = cv2.imread('Alien.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:
# ABEDEPGHIIKRM
# NOLO SICA DOG 4
# ABEDEPGHIIKRM
# NOLO SICA DOG 4

# %%
plot_image(img)

# %%
img = cv2.imread('TimesNewRoman.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:
# ABCDEFGHI
# OR INLO) ZO) is
# STUVWXYZ
# abcdefghijklm
# nopqrstuvwxyZ
# 0123456789

# %%
plot_image(img)

# %%
img = cv2.imread('handwritten.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:
# ABOCBEFGHIFKEM
# NQOPORSTUUUXGZ
# whedetghighle
# pars nome
# 0123456789 !P 4

# %%
plot_image(img)

# %%
img = cv2.imread('realHandwritten.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:
# Hey Clidabeth,
#
# E wont to congratulate you for what youve
# accomplished recently.
#
# Tow have worked so hart over tre last decade
# iv) ge fo umere wen are now. four deserre all
# of the success that you now enjoy.
#
# Keep working hard and vever wee Conplacent!
# See yow STOW,
#
# George.

# %%
plot_image(img)

# %%
img = cv2.imread('FontGlitch.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray, img_bin = cv2.threshold(gray,128,255,cv2.THRESH_BINARY | cv2.THRESH_OTSU)
gray = cv2.bitwise_not(img_bin)

# %%
kernel = np.ones((2, 1), np.uint8)
img = cv2.erode(gray, kernel, iterations=1)
img = cv2.dilate(img, kernel, iterations=1)
out_below = pytesseract.image_to_string(img)
print("OUTPUT:")
print(out_below)
# Out:
# OUTPUT:
# £3 -*x
# QO “OO s
# Gk Ze WN
#
# W= GD

# %%
plot_image(img)

# %% [markdown]
# ## Getting boxes around the text

# %%
img = cv2.imread('ComicSans.jpg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
img = cv2.imread('Jokerman.jpg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
img = cv2.imread('OldEnglish.jpeg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1

# %%
img = cv2.imread('whitespace.jpg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# [ WARN:0@1520.803] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('whitespace.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/v0/kzcv06jd4gl65m0r31wybpxm0000gn/T/ipykernel_7757/626681837.py in <module>
#       1 img = cv2.imread('whitespace.jpg')
# ----> 2 h, w, c = img.shape
#       3 boxes = pytesseract.image_to_boxes(img)
#       4 for b in boxes.splitlines():
#       5     b = b.split(' ')
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
img = cv2.imread('sharp.jpg')
h, w= img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# [ WARN:0@1503.162] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('sharp.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/v0/kzcv06jd4gl65m0r31wybpxm0000gn/T/ipykernel_7757/4183718966.py in <module>
#       1 img = cv2.imread('sharp.jpg')
# ----> 2 h, w= img.shape
#       3 boxes = pytesseract.image_to_boxes(img)
#       4 for b in boxes.splitlines():
#       5     b = b.split(' ')
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
img = cv2.imread('3DNoise.jpeg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
img = cv2.imread('Alien.jpeg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
img = cv2.imread('TimesNewRoman.jpg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
img = cv2.imread('handwritten.jpg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
img = cv2.imread('realHandwritten.jpg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)

# %%
img = cv2.imread('FontGlitch.jpeg')
h, w, c = img.shape
boxes = pytesseract.image_to_boxes(img)
for b in boxes.splitlines():
    b = b.split(' ')
    img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.waitKey(1)
